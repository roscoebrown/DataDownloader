# %%
# from grabRigData import grabtxrrcdata
from postgresCheck import postgresCheck
# from postgresPush import pushRigs


import re
import os
import ast
import PyPDF2 as p2
from pdfminer.high_level import extract_text
import pandas as pd
from pdfminer.converter import TextConverter
import ocrmypdf

import timeit
import time

# %%
class fahimsCrawler():
    
    def __init__(self,path ='C:/Users/Fahim/Desktop/Gibson Reports/AI/Temp3'):
        self.path = path
        os.chdir('C:/Users/Fahim/Desktop/Gibson Reports/AI')
        
        file = open("companyDict.txt","r")
        contents = file.read()
        self.companyDict = ast.literal_eval(contents)
        file.close()
        
        os.chdir(self.path)
        self.rigdb = pd.DataFrame(columns = ['externalattachmentid','rigname'])
#         path, dirs, files = next(os.walk(self.path))
#         self.count = len(files) #count number of files in the directory
    
    
    ###########                             ocr  (optional level)                                ####################   
    
    def ocr(self,filename):
        
        ocrmypdf.ocr(filename,filename,force = True)
        
        return
    
    ###########                     crosscheck sql and extract rig name                         ####################
    
    def getMethod(self,company):
        
        methodName = self.companyDict[company] #returns a list
        module = 'rigExtractor'
        
#         print(methodName)
        
#         importedMethodList = []
        instanceMethodList = []
        
        for imports in methodName:
    
            method = getattr(__import__(module, fromlist=[imports]), imports) 
            m = method()
            instanceMethodList.append(m)
            
            
        
        return instanceMethodList
        
    
    def crawl(self):
        pg = postgresCheck() # instantiating postgresCheck class
        
        count = 0
        
        for file in os.listdir(self.path):
            if file.endswith('.pdf'):
                
                count += 1
                ID = file.split('_')[2].replace('.pdf','')
                
                print('Processing File Numner: ',count,'----------------------------------------------\n')
                
                tags = pg.checkFile(file) #using postgresCheck class
    
                if tags != 'missing':
                    if tags[1] != 'OTHER':
                    
                        if pg.checkRig(file) == 'missing':
                    
                            try:
                                os.chdir(self.path)

                                methodsList = self.getMethod(tags[0])

                                rigName= None

                                for method in methodsList:
                                    if rigName == None:
                                        rigName = method.main(file)


    #                             print(tags[0],file,rigName)

                                if rigName != None:
                                    self.rigdb = self.rigdb.append({'externalattachmentid':ID, 'rigname':rigName} , ignore_index = True)
                                    print('Rig Added!')



                            except Exception as ex:
                                print('\n',ex,file,'\n' )
                        else:
                            print('Already crawled')
                            
#                 else:
#                     print('Document not found in postgres database!')
                            
        pg.cur1.close()
        pg.cur2.close()
        pg.conn.close()
        
        return self.rigdb
    
    ###########                      Push rig names to sql database                         ####################
    def push(self):
        
        pr = pushRigs()
        pr.push(self.rigdb)
        
        return
    
    ###########                      Main program to execute the class                        ####################
    
    def main(self):
        return

# %%
## Running program without using main:

# %%
os.chdir('C:/Users/Fahim/Desktop/Gibson Reports/AI/Temp3')

# %%
tik = time.perf_counter()
f = fahimsCrawler()
rigs = f.crawl()
tok = time.perf_counter()
print('The program took', tok-tik, 'seconds to run')
# Out:
# Processing File Numner:  1 ----------------------------------------------
# Scanning contents: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  2.99page/s]
# OCR:   0%|                                                                                 | 0.0/1.0 [00:00<?, ?page/s]   **** Error: stream operator isn't terminated by valid EOL.
#                Output may be incorrect.
#    **** Error: stream operator isn't terminated by valid EOL.
#                Output may be incorrect.
#
# OCR:  50%|████████████████████████████████████▌                                    | 0.5/1.0 [00:06<00:06, 12.76s/page][tesseract] lots of diacritics - possibly poor OCR
# OCR: 100%|█████████████████████████████████████████████████████████████████████████| 1.0/1.0 [00:06<00:00,  6.54s/page]
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  2 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  3 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  4 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  5 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  6 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  7 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  8 ----------------------------------------------
#
# Processing File Numner:  9 ----------------------------------------------
#
# Processing File Numner:  10 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  11 ----------------------------------------------
#
# Processing File Numner:  12 ----------------------------------------------
#
# Processing File Numner:  13 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  14 ----------------------------------------------
#
# Processing File Numner:  15 ----------------------------------------------
#
# Processing File Numner:  16 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  17 ----------------------------------------------
#
# Processing File Numner:  18 ----------------------------------------------
#
# Processing File Numner:  19 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  20 ----------------------------------------------
#
# Processing File Numner:  21 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  22 ----------------------------------------------
#
# Processing File Numner:  23 ----------------------------------------------
#
# Processing File Numner:  24 ----------------------------------------------
#
# Processing File Numner:  25 ----------------------------------------------
#
# Processing File Numner:  26 ----------------------------------------------
#
#
#  Invalid dictionary construct: [/'Type', /'XObject', /'Subtype', /'Image', /'Width', 478, /'Height', 107, /'ColorSpace', [/'Indexed', /'DeviceRGB\x00255', b'\x00\x00\x00\x80\x00\x00\x00\x80\x00\x80\x80\x00\x00\x00\x80\x80\x00\x80\x00\x80\x80\xc0\xc0\xc0\xc0\xdc\xc0\xa6\xca\xf0\x00\x00\x00\x00\x003\x00\x00f\x00\x00\x99\x00\x00\xcc\x00\x00\xff\x003\x00\x0033\x003f\x003\x99\x003\xcc\x003\xff\x00f\x00\x00f3\x00ff\x00f\x99\x00f\xcc\x00f\xff\x00\x99\x00\x00\x993\x00\x99f\x00\x99\x99\x00\x99\xcc\x00\x99\xff\x00\xcc\x00\x00\xcc3\x00\xccf\x00\xcc\x99\x00\xcc\xcc\x00\xcc\xff\x00\xff\x00\x00\xff3\x00\xfff\x00\xff\x99\x00\xff\xcc\x00\xff\xff3\x00\x003\x0033\x00f3\x00\x993\x00\xcc3\x00\xff33\x0033333f33\x9933\xcc33\xff3f\x003f33ff3f\x993f\xcc3f\xff3\x99\x003\x9933\x99f3\x99\x993\x99\xcc3\x99\xff3\xcc\x003\xcc33\xccf3\xcc\x993\xcc\xcc3\xcc\xff3\xff\x003\xff33\xfff3\xff\x993\xff\xcc3\xff\xfff\x00\x00f\x003f\x00ff\x00\x99f\x00\xccf\x00\xfff3\x00f33f3ff3\x99f3\xccf3\xffff\x00ff3fffff\x99ff\xccff\xfff\x99\x00f\x993f\x99ff\x99\x99f\x99\xccf\x99\xfff\xcc\x00f\xcc3f\xccff\xcc\x99f\xcc\xccf\xcc\xfff\xff\x00f\xff3f\xffff\xff\x99f\xff\xccf\xff\xff\x99\x00\x00\x99\x003\x99\x00f\x99\x00\x99\x99\x00\xcc\x99\x00\xff\x993\x00\x9933\x993f\x993\x99\x993\xcc\x993\xff\x99f\x00\x99f3\x99ff\x99f\x99\x99f\xcc\x99f\xff\x99\x99\x00\x99\x993\x99\x99f\x99\x99\x99\x99\x99\xcc\x99\x99\xff\x99\xcc\x00\x99\xcc3\x99\xccf\x99\xcc\x99\x99\xcc\xcc\x99\xcc\xff\x99\xff\x00\x99\xff3\x99\xfff\x99\xff\x99\x99\xff\xcc\x99\xff\xff\xcc\x00\x00\xcc\x003\xcc\x00f\xcc\x00\x99\xcc\x00\xcc\xcc\x00\xff\xcc3\x00\xcc33\xcc3f\xcc3\x99\xcc3\xcc\xcc3\xff\xccf\x00\xccf3\xccff\xccf\x99\xccf\xcc\xccf\xff\xcc\x99\x00\xcc\x993\xcc\x99f\xcc\x99\x99\xcc\x99\xcc\xcc\x99\xff\xcc\xcc\x00\xcc\xcc3\xcc\xccf\xcc\xcc\x99\xcc\xcc\xcc\xcc\xcc\xff\xcc\xff\x00\xcc\xff3\xcc\xfff\xcc\xff\x99\xcc\xff\xcc\xcc\xff\xff\xff\x00\x00\xff\x003\xff\x00f\xff\x00\x99\xff\x00\xcc\xff\x00\xff\xff3\x00\xff33\xff3f\xff3\x99\xff3\xcc\xff3\xff\xfff\x00\xfff3\xffff\xfff\x99\xfff\xcc\xfff\xff\xff\x99\x00\xff\x993\xff\x99f\xff\x99\x99\xff\x99\xcc\xff\x99\xff\xff\xcc\x00\xff\xcc3\xff\xccf\xff\xcc\x99\xff\xcc\xcc\xff\xcc\xff\xff\xff\x00\xff\xff3\xff\xfff\xff\xff\x99\xff\xff\xcc\xff\xff\xff\x00\x00\x00\r\r\r\x1a\x1a\x1a(((555CCCPPP]]]kkkxxx\x86\x86\x86\x93\x93\x93\xa1\xa1\xa1\xae\xae\xae\xbb\xbb\xbb\xc9\xc9\xc9\xd6\xd6\xd6\xe4\xe4\xe4\xf1\xf1\xf1\xff\xff\xff\xff\xfb\xf0\xa0\xa0\xa4\x80\x80\x80\xff\x00\x00\x00\xff\x00\xff\xff\x00\x00\x00\xff\xff\x00\xff\x00\xff\xff\xff\xff\xff'], /b'\x00', /'BitsPerComponent', 8, /'Length', 9830, /'Filter', /'FlateDecode', /'DecodeParms', {'Predictor': 15, 'Colors': 1, 'BitsPerComponent': 8, 'Columns': 478}] dir_survey_5209106.pdf
#
# Processing File Numner:  27 ----------------------------------------------
#
# Processing File Numner:  28 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  29 ----------------------------------------------
#
# Processing File Numner:  30 ----------------------------------------------
#
# Processing File Numner:  31 ----------------------------------------------
#
# Processing File Numner:  32 ----------------------------------------------
#
# Processing File Numner:  33 ----------------------------------------------
#
# Processing File Numner:  34 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  35 ----------------------------------------------
#
# Processing File Numner:  36 ----------------------------------------------
#
# Processing File Numner:  37 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  38 ----------------------------------------------
#
# Processing File Numner:  39 ----------------------------------------------
#
# Processing File Numner:  40 ----------------------------------------------
#
# Processing File Numner:  41 ----------------------------------------------
#
# Processing File Numner:  42 ----------------------------------------------
#
# Processing File Numner:  43 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  44 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  45 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  46 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  47 ----------------------------------------------
#
# Processing File Numner:  48 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  49 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  50 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  51 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  52 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  53 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  54 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  55 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  56 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  57 ----------------------------------------------
#
#
#  'KINGSLEY DIREC, LLC, A TX LLC' dir_survey_5210070.pdf
#
# Processing File Numner:  58 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  59 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  60 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  61 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  62 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  63 ----------------------------------------------
#
#
#  'LEAM DRILLING SERVICES' dir_survey_5210951.pdf
#
# Processing File Numner:  64 ----------------------------------------------
#
#
#  'LEAM DRILLING SERVICES' dir_survey_5210955.pdf
#
# Processing File Numner:  65 ----------------------------------------------
#
#
#  'LEAM DRILLING SERVICES' dir_survey_5210964.pdf
#
# Processing File Numner:  66 ----------------------------------------------
#  'LEAM DRILLING SERVICES' dir_survey_5210970.pdf
#
# Processing File Numner:  67 ----------------------------------------------
# Scanning contents: 100%|███████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.69page/s]
# OCR: 100%|█████████████████████████████████████████████████████████████████████████| 4.0/4.0 [00:38<00:00,  9.59s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  68 ----------------------------------------------
#
# Processing File Numner:  69 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  70 ----------------------------------------------
#
#
#  'WESTCOTT DOWN HOLE SERV, INC.' dir_survey_5211060.pdf
#
# Processing File Numner:  71 ----------------------------------------------
#
#
#  'MS ENERGY SERVICES' dir_survey_5211083.pdf
#
# Processing File Numner:  72 ----------------------------------------------
#
#
#  'MS ENERGY SERVICES' dir_survey_5211102.pdf
#
# Processing File Numner:  73 ----------------------------------------------
#
#
#  'MS ENERGY SERVICES' dir_survey_5211104.pdf
#
# Processing File Numner:  74 ----------------------------------------------
#
#
#  'MS ENERGY SERVICES' dir_survey_5211142.pdf
#
# Processing File Numner:  75 ----------------------------------------------
#
#
#  'MS ENERGY SERVICES' dir_survey_5211325.pdf
#
# Processing File Numner:  76 ----------------------------------------------
#
#
#  'MS ENERGY SERVICES' dir_survey_5211346.pdf
#
# Processing File Numner:  77 ----------------------------------------------
#
#
#  'MS ENERGY SERVICES' dir_survey_5211350.pdf
#
# Processing File Numner:  78 ----------------------------------------------
# Scanning contents: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  8.52page/s]
# OCR: 100%|█████████████████████████████████████████████████████████████████████████| 1.0/1.0 [00:10<00:00, 10.86s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  79 ----------------------------------------------
# Scanning contents: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  6.19page/s]
# OCR: 100%|███████████████████████████████████████████████████████████████████████| 10.0/10.0 [00:21<00:00,  2.12s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  80 ----------------------------------------------
# Scanning contents: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:02<00:00,  4.38page/s]
# OCR: 100%|███████████████████████████████████████████████████████████████████████| 10.0/10.0 [00:24<00:00,  2.43s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  81 ----------------------------------------------
# Scanning contents: 100%|█████████████████████████████████████████████████████████████| 20/20 [00:02<00:00,  7.83page/s]
# OCR: 100%|███████████████████████████████████████████████████████████████████████| 20.0/20.0 [00:31<00:00,  1.56s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Processing File Numner:  82 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  83 ----------------------------------------------
#
# Processing File Numner:  84 ----------------------------------------------
# Scanning contents: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.35page/s]
# OCR: 100%|█████████████████████████████████████████████████████████████████████████| 1.0/1.0 [00:09<00:00,  9.78s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  85 ----------------------------------------------
# Scanning contents: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  6.14page/s]
# OCR: 100%|███████████████████████████████████████████████████████████████████████| 10.0/10.0 [00:21<00:00,  2.14s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  86 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  87 ----------------------------------------------
#
# Processing File Numner:  88 ----------------------------------------------
# Scanning contents: 100%|███████████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  9.07page/s]
# OCR: 100%|█████████████████████████████████████████████████████████████████████████| 1.0/1.0 [00:10<00:00, 10.07s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  89 ----------------------------------------------
# Scanning contents: 100%|█████████████████████████████████████████████████████████████| 10/10 [00:01<00:00,  5.73page/s]
# OCR: 100%|███████████████████████████████████████████████████████████████████████| 10.0/10.0 [00:24<00:00,  2.45s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  90 ----------------------------------------------
#
# Processing File Numner:  91 ----------------------------------------------
#
# Processing File Numner:  92 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  93 ----------------------------------------------
#
# Processing File Numner:  94 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  95 ----------------------------------------------
#
# Processing File Numner:  96 ----------------------------------------------
# Scanning contents: 100%|███████████████████████████████████████████████████████████████| 8/8 [00:01<00:00,  4.11page/s]
# OCR: 100%|█████████████████████████████████████████████████████████████████████████| 8.0/8.0 [00:31<00:00,  3.90s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  97 ----------------------------------------------
#
# Processing File Numner:  98 ----------------------------------------------
#
#
#  'M3P DIRECTIONAL SERVICES, LTD.' dir_survey_5211841.pdf
#
# Processing File Numner:  99 ----------------------------------------------
#
#
#  'STRYKER ENERGY DIRCTNL SRVCS,LLC' dir_survey_5211887.pdf
#
# Processing File Numner:  100 ----------------------------------------------
# Scanning contents: 100%|███████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.75page/s]
# OCR: 100%|█████████████████████████████████████████████████████████████████████████| 3.0/3.0 [00:37<00:00, 12.36s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  101 ----------------------------------------------
#
# Processing File Numner:  102 ----------------------------------------------
# Scanning contents: 100%|███████████████████████████████████████████████████████████████| 3/3 [00:00<00:00, 11.79page/s]
# OCR: 100%|█████████████████████████████████████████████████████████████████████████| 3.0/3.0 [00:37<00:00, 12.44s/page]
# Some input metadata could not be copied because it is not permitted in PDF/A. You may wish to examine the output PDF's XMP metadata.
# JPEGs: 0image [00:00, ?image/s]
# JBIG2: 0item [00:00, ?item/s]
# Rig Added!
# Processing File Numner:  103 ----------------------------------------------
#
# Processing File Numner:  104 ----------------------------------------------
#
#
#  'STRYKER ENERGY DIRCTNL SRVCS,LLC' dir_survey_5212011.pdf
#
# Processing File Numner:  105 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  106 ----------------------------------------------
#
# Processing File Numner:  107 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  108 ----------------------------------------------
#
# Processing File Numner:  109 ----------------------------------------------
#
# Processing File Numner:  110 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  111 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  112 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  113 ----------------------------------------------
#
# Processing File Numner:  114 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  115 ----------------------------------------------
#
# Processing File Numner:  116 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  117 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  118 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  119 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  120 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  121 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  122 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  123 ----------------------------------------------
#
#
#  'STRYKER ENERGY DIRCTNL SRVCS,LLC' dir_survey_5212465.pdf
#
# Processing File Numner:  124 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  125 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  126 ----------------------------------------------
#
# Rig Added!
# Processing File Numner:  127 ----------------------------------------------
#
# Processing File Numner:  128 ----------------------------------------------
#
# Processing File Numner:  129 ----------------------------------------------
#
# Processing File Numner:  130 ----------------------------------------------
#
# Processing File Numner:  131 ----------------------------------------------
#
# Processing File Numner:  132 ----------------------------------------------
#
# Processing File Numner:  133 ----------------------------------------------
#
# Processing File Numner:  134 ----------------------------------------------
#
# Processing File Numner:  135 ----------------------------------------------
#
# Processing File Numner:  136 ----------------------------------------------
#
# Processing File Numner:  137 ----------------------------------------------
#
# Processing File Numner:  138 ----------------------------------------------
#
# Processing File Numner:  139 ----------------------------------------------
#
# Processing File Numner:  140 ----------------------------------------------
#
# Processing File Numner:  141 ----------------------------------------------
#
# Processing File Numner:  142 ----------------------------------------------
#
# Processing File Numner:  143 ----------------------------------------------
#
# Processing File Numner:  144 ----------------------------------------------
#
# Processing File Numner:  145 ----------------------------------------------
#
# Processing File Numner:  146 ----------------------------------------------
#
# Processing File Numner:  147 ----------------------------------------------
#
# Processing File Numner:  148 ----------------------------------------------
#
# Processing File Numner:  149 ----------------------------------------------
#
# Processing File Numner:  150 ----------------------------------------------
#
# Processing File Numner:  151 ----------------------------------------------
#
# Processing File Numner:  152 ----------------------------------------------
#
# Processing File Numner:  153 ----------------------------------------------
#
# Processing File Numner:  154 ----------------------------------------------
#
# Processing File Numner:  155 ----------------------------------------------
#
# Processing File Numner:  156 ----------------------------------------------
#
# Processing File Numner:  157 ----------------------------------------------
#
# Processing File Numner:  158 ----------------------------------------------
#
# Processing File Numner:  159 ----------------------------------------------
#
# Processing File Numner:  160 ----------------------------------------------
#
# Processing File Numner:  161 ----------------------------------------------
#
# Processing File Numner:  162 ----------------------------------------------
#
# Processing File Numner:  163 ----------------------------------------------
#
# Processing File Numner:  164 ----------------------------------------------
#
# Processing File Numner:  165 ----------------------------------------------
#
# Processing File Numner:  166 ----------------------------------------------
#
# Processing File Numner:  167 ----------------------------------------------
#
# Processing File Numner:  168 ----------------------------------------------
#
# Processing File Numner:  169 ----------------------------------------------
#
# Processing File Numner:  170 ----------------------------------------------
#
# Processing File Numner:  171 ----------------------------------------------
#
# Processing File Numner:  172 ----------------------------------------------
#
# Processing File Numner:  173 ----------------------------------------------
#
# Processing File Numner:  174 ----------------------------------------------
#
# Processing File Numner:  175 ----------------------------------------------
#
# Processing File Numner:  176 ----------------------------------------------
#
# Processing File Numner:  177 ----------------------------------------------
#
# Processing File Numner:  178 ----------------------------------------------
#
# Processing File Numner:  179 ----------------------------------------------
#
# Processing File Numner:  180 ----------------------------------------------
#
# Processing File Numner:  181 ----------------------------------------------
#
# Processing File Numner:  182 ----------------------------------------------
#
# Processing File Numner:  183 ----------------------------------------------
#
# Processing File Numner:  184 ----------------------------------------------
#
# Processing File Numner:  185 ----------------------------------------------
#
# Processing File Numner:  186 ----------------------------------------------
#
# Processing File Numner:  187 ----------------------------------------------
#
# Processing File Numner:  188 ----------------------------------------------
#
# Processing File Numner:  189 ----------------------------------------------
#
# Processing File Numner:  190 ----------------------------------------------
#
# Processing File Numner:  191 ----------------------------------------------
#
# Processing File Numner:  192 ----------------------------------------------
#
# Processing File Numner:  193 ----------------------------------------------
#
# Processing File Numner:  194 ----------------------------------------------
#
# Processing File Numner:  195 ----------------------------------------------
#
# Processing File Numner:  196 ----------------------------------------------
#
# Processing File Numner:  197 ----------------------------------------------
#
# Processing File Numner:  198 ----------------------------------------------
#
# Processing File Numner:  199 ----------------------------------------------
#
# Processing File Numner:  200 ----------------------------------------------
#
# The program took 886.9412183 seconds to run

# %%
rigs = f.rigdb

# %%
rigs['rigname'] = rigs['rigname'].str.upper()
rigs['rigname'] = rigs['rigname'].str.strip()

# %%
# print(rigs)
# Out:
#    externalattachmentid         rigname
# 0               5208026      CARTEL  41
# 1               5208237         H&P 540
# 2               5208326  PINNERGY RIG 3
# 3               5208412         H&P 553
# 4               5208537     ENSIGN #106
# ..                  ...             ...
# 60              5212447          HP 375
# 61              5212450         RFC 103
# 62              5212527        H&P #505
# 63              5212529        H&P #505
# 64              5212551     ENSIGN #108
#
# [65 rows x 2 columns]

# %%
os.chdir('C:/Users/Fahim/Desktop/Gibson Reports/AI') ## export path
rigs.to_csv('Rigsv8.csv',index = False)
